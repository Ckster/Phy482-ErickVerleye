# %%
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline

R=1
L=1
V0=1
C=1
t=2*np.pi
phi = np.arctan(R*(w**2*L*C -1)/(w*L))
W=[]
I=[]
w=-10*np.pi
dw=.1
while w <(10*np.pi):
    Curr = V0*np.cos(w*t + phi)*((w*L)**2 + (R*w**2*L*C - R)**2)**(1/2)/(R*L*w)
    I.append(Curr)
    W.append(w)
    w += dw
plt.plot(W,I)
