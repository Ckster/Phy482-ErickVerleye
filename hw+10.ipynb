# %%
lam=4e-9
k=2*np.pi/lam
x=np.linspace(0,100,100)
f=np.zeros_like(x)

for i in range(0,len(x)):
    f[i]=1/(2*np.pi)**2*np.cos(np.deg2rad(k*x[i]))
plt.plot(x,f)

plt.xlabel('position')
plt.ylabel('Functional value')
# Out:
# Text(0,0.5,'Functional value')
